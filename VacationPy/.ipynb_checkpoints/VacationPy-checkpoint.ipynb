# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#having trouble getting gmap module recognized as installed using this as a work-around
import sys 
# !{sys.executable} -m pip install gmaps

# %%
import sys 
# !{sys.executable}  -m jupyter nbextension enable --py gmaps
# !{sys.executable}  -m jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import pprint
import json 

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#import city weather data from Weatherpy

# Study data files
weather_metadata_path = "C:/Users/mike1/OneDrive/Desktop/weather_df.csv"

# Read the mouse data and the study results
weather_df = pd.read_csv(weather_metadata_path)


# Read weather_df.cvs file and store into Pandas data frame
weather_df.head()
# Out:
#    Unnamed: 0             City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           0          Rikitea -23.12 -134.97     23.22        76          61
# 1           1            Vaini -21.20 -175.20     22.00        94          20
# 2           2            Kapaa  22.08 -159.32     26.00        78          20
# 3           3  Arraial do Cabo -22.97  -42.03     28.00        78          40
# 4           4      Yellowknife  62.46 -114.35     -2.22        79          75
#
#    Wind Speed Country        Date
# 0        7.55      PF  1604944827
# 1        2.10      TO  1604944852
# 2        8.20      US  1604944657
# 3        4.10      BR  1604944567
# 4        1.50      CA  1604944642

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
 # Store latitude and longitude in locations
locations = weather_df[["Lat", "Lng"]].astype(float)

#Store humidity data in this list
humidity =  weather_df["Humidity"].astype(float)



# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
#fig.add_layer(heat_layer)



# # Customize the size of the figure
figure_layout = {
    'width': '1200px',
    'height': '700px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)
# Add layer
fig.add_layer(heat_layer)

#Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='700px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Convert Max Temp values to fahrenheit 

#convert_temp_weather_df = weather_df.loc[(weather_df['Max Temp'])].apply(convert_fah)

# weather_df['Max Temp'] = weather_df['Max Temp'].apply(f)

# def convert_fah():
#     Max Temp = Max Temp * 1.8 +32
#     return float(Max Temp)




#custom_weather_df = weather_df.loc[(weather_df['Max Temp']<=29.9 & (weather_df['Max Temp'] >=21.1)) & (weather_df['Wind Speed']< 10)
#                & (weather_df['Cloudiness'] ==0)]

custom_weather_df = weather_df.loc[(weather_df['Max Temp']<=29.9) & (weather_df['Max Temp']>=21.1) & (weather_df['Wind Speed']< 10)
                & (weather_df['Cloudiness'] ==0)]
custom_weather_df
# Out:
#      Unnamed: 0            City    Lat     Lng  Max Temp  Humidity  \
# 45           45  Saint-Philippe -21.36   55.77     24.00        73
# 102         102          Najrān  17.49   44.13     24.00        29
# 126         126          Riyadh  24.69   46.72     26.00        36
# 206         206           Buala  -8.14  159.59     26.87        80
# 217         217           Bilma  18.69   12.92     23.33        28
# 224         224          Yārāda  17.65   83.27     23.00        78
# 246         246          Mahuva  21.09   71.76     26.41        34
# 335         335      Anakapalle  17.68   83.02     23.00        78
# 346         346    Port Hedland -20.32  118.57     25.00        73
# 362         362            Mauá -23.67  -46.46     28.00        54
# 413         413      Nouadhibou  20.93  -17.03     24.00        57
# 426         426   Narasannapeta  18.42   84.05     21.14        67
# 487         487         Salalah  17.02   54.09     27.00        65
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types

# Import API key
from api_keys import g_key
hotel_df = []

#hotel_df['Hotel Name'] = ''
#hotel_df = hotel_df.assign(Hotel Name = '')
hotel_df.insert(0, 'Hotel Name')

#parameter values
locations = custom_weather_df[["Lat", "Lng"]].astype(float)
target_type = "lodging"
radius = 5000

#parameter dict 
params = {
    "location": locations,
    "types": target_type,
    "radius": radius,
    "key": g_key
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#https://maps.googleapis.com/maps/api/place/findplacefromtext/output?parameters

# %%
target_type = "lodging"
seattle_coords = "-21.36,55.77"
radius = 5000

# rewrite params dict

params = {
    "location": seattle_coords,
    "types": target_type,
    "radius": radius,
    "key": g_key
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"




# Identify nearest city for each lat, lng combination
for location in locations:
     
    # Run request
    response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key

response_json = response.json()
#hotels_json_object = response.json()

#pprint.pprint(response_json)

print(f'next pretty print**************')
      
pprint.pprint(json.dumps(response_json, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
# print(seattle_bikes["results"][0]["name"])
# print(seattle_bikes["results"][0]["vicinity"])
# Out:
# next pretty print**************
# ('{\n'
#  '    "html_attributions": [],\n'
#  '    "results": [\n'
#  '        {\n'
#  '            "business_status": "OPERATIONAL",\n'
#  '            "geometry": {\n'
#  '                "location": {\n'
#  '                    "lat": -21.358434,\n'
#  '                    "lng": 55.77032209999999\n'
#  '                },\n'
#  '                "viewport": {\n'
#  '                    "northeast": {\n'
#  '                        "lat": -21.3570810697085,\n'
#  '                        "lng": 55.7717046302915\n'
#  '                    },\n'
#  '                    "southwest": {\n'
#  '                        "lat": -21.3597790302915,\n'
#  '                        "lng": 55.7690066697085\n'
#  '                    }\n'
#  '                }\n'
#  '            },\n'
#  '            "icon": '
#  '"https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",\n'
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig

# Display figure
