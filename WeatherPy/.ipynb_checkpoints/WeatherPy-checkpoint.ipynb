# %% [markdown]
# # WeatherPy
# ----
#
# #### Observations
# - There is a sigificant correction between temperature and latitude in the sample in the northern hemisphere, but not so much for cities in the southern hemisphere.

# %% [markdown]
# ![fig5.png](attachment:fig5.png)

# %% [markdown]
# - Based on this scatter, it is warmer closer to the equator.
# ![fig1.png](attachment:fig1.png)

# %% [markdown]
# - Regardless of location, wind speed is mostly below 10 mph.
# ![fig4.png](attachment:fig4.png)

# %%
# I initally used pip to install citpy in the console and was successful 
#in retrieving the city and weather data. Next day my notebook would not 
#recongnize citipy as installed. Had to use 'import sys' in the notebook to resolve.

#import sys 
#!{sys.executable} -m pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import time
import pprint
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file_1 = "output_data/cities_df.cvs"
output_data_file_2 = "output_data/weather_df.cvs"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print(weather_api_key)
# Out:
# 73ceaec8da4e2e6bacfe71e5777e5c6f

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

#convert list into a dataframe
cities_df = pd.DataFrame(cities)
#print dataframe to a cvs file
cities_df.to_csv(output_data_file_1)

# %%
# Study data files
weather_metadata_path = "/output_data/weather_df.csv"

# Read the mouse data and the study results
cities = pd.read_csv(weather_metadata_path)

#cities1 = cities(['City'])
# Read weather_df.cvs file and store into Pandas data frame
cities.head(50)
cities1 = cities["City"]


cities1
# Out:
# 0              Rikitea
# 1                Vaini
# 2                Kapaa
# 3      Arraial do Cabo
# 4          Yellowknife
#             ...
# 554        Bongandanga
# 555        San Quintín
# 556            Kajiado
# 557          Mongoumba
# 558         Hammerfest
# Name: City, Length: 559, dtype: object

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API Call
#Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="


#test data used to for initial runs of the loop
#cities = ["Paris", "London", "Oslo", "Beijing", "Jokie Dokie", "Mumbai", "Manila", "New York", "Seattle", "Dallas", "Taipei"]

# set up lists to hold reponse info


lat = []
lng = []
temp_max = []
city_2 = []
humidity = []
cloudiness = []
wind_speed = []
city_name = []
country = []
date = []
count = 0
set_number = 1




import pprint
#pprint.pprint(response)

#Loop through the list of cities and perform a request for data on each
print(f'Beginning Data Retrieval')
print(f'---------------------------')

#loop trought the cities                        
for city in cities:
    # API requests and append data to emptly lists predefined
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        #counters for the sets
        if count >= 50: 
            count = 1
            set_number =set_number + 1
            city_2.append(city)
        else:
            count += 1
            city_2.append(city)
           
        print(f'Processing Record {count} of Set {set_number} | {city}')  
    
    except KeyError:
        print(f'City Not Found...Skipping...')
    
print(f'-------------------------------')
print(f'     End of Data Retrieval  \n Data for {len(city_name)} cities retrieved')
print(f'-------------------------------')
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | Rikitea
# Processing Record 2 of Set 1 | Vaini
# Processing Record 3 of Set 1 | Kapaa
# Processing Record 4 of Set 1 | Arraial do Cabo
# Processing Record 5 of Set 1 | Yellowknife
# Processing Record 6 of Set 1 | Busselton
# Processing Record 7 of Set 1 | Oktyabr'skiy
# Processing Record 8 of Set 1 | Maniitsoq
# Processing Record 9 of Set 1 | Shangzhi
# Processing Record 10 of Set 1 | Albany
# Processing Record 11 of Set 1 | Grand Gaube
# Processing Record 48 of Set 3 | Broome
# Processing Record 49 of Set 3 | Coyhaique
# Processing Record 50 of Set 3 | Beloha
# Processing Record 1 of Set 4 | Pangnirtung
# Processing Record 2 of Set 4 | Mahenge
# Processing Record 3 of Set 4 | Mezen'
# Processing Record 4 of Set 4 | Geraldton
# Processing Record 5 of Set 4 | Pevek
# Processing Record 6 of Set 4 | Sitia
# Processing Record 7 of Set 4 | Dunedin
# Processing Record 8 of Set 4 | Kochki
# Processing Record 9 of Set 4 | Bredasdorp
# Processing Record 10 of Set 4 | Kavieng
# Processing Record 11 of Set 4 | Egvekinot
# Processing Record 12 of Set 4 | Tigil'
# Processing Record 13 of Set 4 | Biak
# Processing Record 14 of Set 4 | Tobias Barreto
# Processing Record 15 of Set 4 | Pacific Grove
# Processing Record 16 of Set 4 | Banda Aceh
# Processing Record 17 of Set 4 | Mana
# Processing Record 18 of Set 4 | Neman
# Processing Record 19 of Set 4 | Raja
# Processing Record 20 of Set 4 | Saint-Augustin
# Processing Record 21 of Set 4 | Ranot
# Processing Record 22 of Set 4 | Nyírbéltek
# Processing Record 23 of Set 4 | Meridian
# Processing Record 24 of Set 4 | Malakal
# Processing Record 25 of Set 4 | Sur
# Processing Record 26 of Set 4 | Bethel
# Processing Record 27 of Set 4 | Nanortalik
# Processing Record 28 of Set 4 | Batangafo
# Processing Record 29 of Set 4 | Parrita
# Processing Record 30 of Set 4 | Margate
# Processing Record 31 of Set 4 | Birin
# Processing Record 32 of Set 4 | Quime
# Processing Record 33 of Set 4 | Laguna
# Processing Record 34 of Set 4 | Yegros
# Processing Record 35 of Set 4 | Vostok
# Processing Record 36 of Set 4 | Fairbanks
# Processing Record 37 of Set 4 | Garoafa
# Processing Record 38 of Set 4 | Mahajanga
# Processing Record 39 of Set 4 | Lodja
# Processing Record 40 of Set 4 | Talnakh
# Processing Record 41 of Set 4 | Hualmay
# Processing Record 42 of Set 4 | Oregon
# Processing Record 43 of Set 4 | Kolda
# Processing Record 44 of Set 4 | Ballina
# Processing Record 45 of Set 4 | Altay
# Processing Record 46 of Set 4 | Puerto Nariño
# Processing Record 47 of Set 4 | Vaghashen
# Processing Record 48 of Set 4 | Comodoro Rivadavia
# Processing Record 49 of Set 4 | Hadejia
# Processing Record 50 of Set 4 | Mar del Plata
# Processing Record 1 of Set 5 | Mitsamiouli
# Processing Record 2 of Set 5 | Lagoa
# Processing Record 3 of Set 5 | Progreso
# Processing Record 4 of Set 5 | Muros
# Processing Record 5 of Set 5 | Ilulissat
# Processing Record 6 of Set 5 | Isla Mujeres
# Processing Record 7 of Set 5 | Buala
# Processing Record 8 of Set 5 | Bathsheba
# Processing Record 9 of Set 5 | Hanzhong
# Processing Record 10 of Set 5 | Hobyo
# Processing Record 11 of Set 5 | Yala
# Processing Record 12 of Set 5 | Puerto Escondido
# Processing Record 13 of Set 5 | Ōdachō-ōda
# Processing Record 14 of Set 5 | Nsoko
# Processing Record 15 of Set 5 | Sitka
# Processing Record 16 of Set 5 | Taitung City
# Processing Record 17 of Set 5 | Vilhena
# Processing Record 18 of Set 5 | Bilma
# Processing Record 19 of Set 5 | Jalu
# Processing Record 20 of Set 5 | Isla Vista
# Processing Record 21 of Set 5 | Pierre
# Processing Record 22 of Set 5 | Cape Town
# Processing Record 23 of Set 5 | Port Alfred
# Processing Record 24 of Set 5 | Bilibino
# Processing Record 25 of Set 5 | Yārāda
# Processing Record 26 of Set 5 | Luwuk
# Processing Record 27 of Set 5 | Sambava
# Processing Record 28 of Set 5 | Coxim
# Processing Record 29 of Set 5 | Kununurra
# Processing Record 30 of Set 5 | Khani
# Processing Record 31 of Set 5 | Zhigansk
# Processing Record 32 of Set 5 | Kaniama
# Processing Record 33 of Set 5 | Takaungu
# Processing Record 34 of Set 5 | Jining
# Processing Record 35 of Set 5 | Panama City
# Processing Record 36 of Set 5 | Aklavik
# Processing Record 37 of Set 5 | Maraã
# Processing Record 38 of Set 5 | Hamilton
# Processing Record 39 of Set 5 | Mount Gambier
# Processing Record 40 of Set 5 | Palu
# Processing Record 41 of Set 5 | Severo-Kuril'sk
# Processing Record 42 of Set 5 | General Roca
# Processing Record 43 of Set 5 | Kars
# Processing Record 44 of Set 5 | Narón
# Processing Record 45 of Set 5 | Los Llanos de Aridane
# Processing Record 46 of Set 5 | Waverly
# Processing Record 47 of Set 5 | Mahuva
# Processing Record 48 of Set 5 | Lázaro Cárdenas
# Processing Record 49 of Set 5 | Daşoguz
# Processing Record 50 of Set 5 | Béboto
# Processing Record 1 of Set 6 | Kyren
# Processing Record 2 of Set 6 | Kahului
# Processing Record 3 of Set 6 | Florianópolis
# Processing Record 4 of Set 6 | Torbay
# Processing Record 5 of Set 6 | Lavrentiya
# Processing Record 6 of Set 6 | Jiangyou
# Processing Record 7 of Set 6 | Ponta Delgada
# Processing Record 8 of Set 6 | Vila Franca do Campo
# Processing Record 9 of Set 6 | Klyuchi
# Processing Record 10 of Set 6 | Phuthaditjhaba
# Processing Record 11 of Set 6 | Bulawayo
# Processing Record 12 of Set 6 | Davila
# Processing Record 13 of Set 6 | Altamont
# Processing Record 14 of Set 6 | Tsogni
# Processing Record 15 of Set 6 | Saldanha
# Processing Record 16 of Set 6 | Broken Hill
# Processing Record 17 of Set 6 | Skibbereen
# Processing Record 18 of Set 6 | Wagar
# Processing Record 19 of Set 6 | Blackwater
# Processing Record 20 of Set 6 | Makanya
# Processing Record 21 of Set 6 | Nieuwpoort
# Processing Record 22 of Set 6 | Buta
# Processing Record 23 of Set 6 | Oeiras do Pará
# Processing Record 24 of Set 6 | Dekar
# Processing Record 25 of Set 6 | Baruun-Urt
# Processing Record 26 of Set 6 | Tawang Town
# Processing Record 27 of Set 6 | Provideniya
# Processing Record 28 of Set 6 | Bolshaya Sosnova
# Processing Record 29 of Set 6 | Ust'-Omchug
# Processing Record 30 of Set 6 | Faya
# Processing Record 31 of Set 6 | Planaltina
# Processing Record 32 of Set 6 | Romny
# Processing Record 33 of Set 6 | Lofthus
# Processing Record 34 of Set 6 | Fuxin
# Processing Record 23 of Set 9 | Hornepayne
# Processing Record 24 of Set 9 | Ashibetsu
# Processing Record 25 of Set 9 | Shelbyville
# Processing Record 26 of Set 9 | Emba
# Processing Record 27 of Set 9 | Narasannapeta
# Processing Record 28 of Set 9 | Buchanan
# Processing Record 29 of Set 9 | Kropotkin
# Processing Record 30 of Set 9 | Neyshabur
# Processing Record 31 of Set 9 | Grindavik
# Processing Record 32 of Set 9 | Ningxiang
# Processing Record 33 of Set 9 | Pemangkat
# Processing Record 34 of Set 9 | Haines Junction
# Processing Record 35 of Set 9 | Chumikan
# Processing Record 36 of Set 9 | Inhambane
# Processing Record 37 of Set 9 | Santoña
# Processing Record 38 of Set 9 | Novy Urengoy
# Processing Record 39 of Set 9 | Adilcevaz
# Processing Record 40 of Set 9 | Río Tercero
# Processing Record 41 of Set 9 | Caucayá
# Processing Record 42 of Set 9 | Arecibo
# Processing Record 43 of Set 9 | Sibolga
# Processing Record 44 of Set 9 | São Filipe
# Processing Record 45 of Set 9 | Honningsvåg
# Processing Record 46 of Set 9 | Sørland
# Processing Record 47 of Set 9 | Labuhan
# Processing Record 48 of Set 9 | Taku
# Processing Record 49 of Set 9 | Srednekolymsk
# Processing Record 50 of Set 9 | Çermik
# Processing Record 1 of Set 10 | Olafsvik
# Processing Record 2 of Set 10 | Imbituba
# Processing Record 3 of Set 10 | Japoatã
# Processing Record 4 of Set 10 | Ovsyanka
# Processing Record 5 of Set 10 | Leh
# Processing Record 6 of Set 10 | Mariakani
# Processing Record 7 of Set 10 | Longyearbyen
# Processing Record 8 of Set 10 | Caravelas
# Processing Record 9 of Set 10 | Gmina Świecie
# Processing Record 10 of Set 10 | Guánica
# Processing Record 11 of Set 10 | Alofi
# Processing Record 12 of Set 10 | Kīhei
# Processing Record 13 of Set 10 | Nanga Eboko
# Processing Record 14 of Set 10 | Oistins
# Processing Record 15 of Set 10 | Chambas
# Processing Record 16 of Set 10 | Dumas
# Processing Record 17 of Set 10 | Acapulco de Juárez
# Processing Record 18 of Set 10 | Tautira
# Processing Record 19 of Set 10 | Amapá
# Processing Record 20 of Set 10 | Périgueux
# Processing Record 21 of Set 10 | Maracaju
# Processing Record 22 of Set 10 | Ayan
# Processing Record 23 of Set 10 | Okmulgee
# Processing Record 24 of Set 10 | Seybaplaya
# Processing Record 25 of Set 10 | Arroyo de la Encomienda
# Processing Record 26 of Set 10 | Arrondissement de Saint-Dizier
# Processing Record 27 of Set 10 | Hay River
# Processing Record 28 of Set 10 | Barra de Tecoanapa
# Processing Record 29 of Set 10 | Svobodnyy
# Processing Record 30 of Set 10 | Álamos
# Processing Record 31 of Set 10 | Sumbe
# Processing Record 32 of Set 10 | Bambanglipuro
# Processing Record 33 of Set 10 | San Luis
# Processing Record 34 of Set 10 | Wenling
# Processing Record 35 of Set 10 | Concarneau
# Processing Record 36 of Set 10 | Avera
# Processing Record 37 of Set 10 | Rosetown
# Processing Record 38 of Set 10 | Salalah
# Processing Record 39 of Set 10 | Port Lincoln
# Processing Record 40 of Set 10 | Bloemfontein
# Processing Record 41 of Set 10 | Jinchang
# Processing Record 42 of Set 10 | San Patricio
# Processing Record 43 of Set 10 | Chicama
# Processing Record 44 of Set 10 | Vestmannaeyjar
# Processing Record 45 of Set 10 | Oddur
# Processing Record 46 of Set 10 | Coruripe
# Processing Record 47 of Set 10 | Lusambo
# Processing Record 48 of Set 10 | Truth or Consequences
# Processing Record 49 of Set 10 | Şile
# Processing Record 50 of Set 10 | Kirakira
# Processing Record 1 of Set 11 | Villamontes
# Processing Record 2 of Set 11 | Issoire
# Processing Record 3 of Set 11 | Luena
# Processing Record 4 of Set 11 | Dutse
# Processing Record 5 of Set 11 | Edd
# Processing Record 6 of Set 11 | Bogdanovich
# Processing Record 7 of Set 11 | Korla
# Processing Record 8 of Set 11 | Prince Rupert
# Processing Record 9 of Set 11 | Makakilo City
# Processing Record 10 of Set 11 | Grøa
# Processing Record 11 of Set 11 | San Rafael del Sur
# Processing Record 12 of Set 11 | Galle
# Processing Record 13 of Set 11 | Harper
# Processing Record 14 of Set 11 | Gbongan
# Processing Record 15 of Set 11 | Castrovillari
# Processing Record 16 of Set 11 | Anloga
# Processing Record 17 of Set 11 | Araouane
# Processing Record 18 of Set 11 | Ustka
# Processing Record 19 of Set 11 | Sampit
# Processing Record 20 of Set 11 | Qaqortoq
# Processing Record 21 of Set 11 | Ganzhou
# Processing Record 22 of Set 11 | Nhulunbuy
# Processing Record 23 of Set 11 | Chiman
# Processing Record 24 of Set 11 | City of San Pedro
# Processing Record 25 of Set 11 | Olden
# Processing Record 26 of Set 11 | Beyneu
# Processing Record 27 of Set 11 | Lochristi
# Processing Record 28 of Set 11 | Longkou
# Processing Record 29 of Set 11 | Katobu
# Processing Record 30 of Set 11 | Tacuatí
# Processing Record 31 of Set 11 | Ilhabela
# Processing Record 32 of Set 11 | Whitehorse
# Processing Record 33 of Set 11 | Monrovia
# Processing Record 34 of Set 11 | Laas
# Processing Record 35 of Set 11 | Malbork
# Processing Record 36 of Set 11 | Mount Isa
# Processing Record 37 of Set 11 | Murakami
# Processing Record 38 of Set 11 | Bayir
# Processing Record 39 of Set 11 | Xiaolingwei
# Processing Record 40 of Set 11 | Saint-François
# Processing Record 41 of Set 11 | Waingapu
# Processing Record 42 of Set 11 | Mabaruma
# Processing Record 43 of Set 11 | Acolla
# Processing Record 44 of Set 11 | Toppenish
# Processing Record 45 of Set 11 | Krosno
# Processing Record 46 of Set 11 | Khingansk
# Processing Record 47 of Set 11 | Petersburg
# Processing Record 48 of Set 11 | Port Macquarie
# Processing Record 49 of Set 11 | Nha Trang
# Processing Record 50 of Set 11 | Shaunavon
# Processing Record 1 of Set 12 | Mogok
# Processing Record 2 of Set 12 | Santa Maria
# Processing Record 3 of Set 12 | Noumea
# Processing Record 4 of Set 12 | Maţāy
# Processing Record 5 of Set 12 | Bongandanga
# Processing Record 6 of Set 12 | San Quintín
# Processing Record 7 of Set 12 | Kajiado
# Processing Record 8 of Set 12 | Mongoumba
# Processing Record 9 of Set 12 | Hammerfest
# -------------------------------
#      End of Data Retrieval
#  Data for 559 cities retrieved
# -------------------------------

# %%
#put response data in to a dict

weather_dict = {
    'City': city_name,
    "Lat": lat,
    'Lng': lng,
    "Max Temp": temp_max,
"Humidity": humidity, 
'Cloudiness': cloudiness, 
'Wind Speed': wind_speed,
'Country': country,
'Date': date}

print(weather_dict)
# Out:
# {'City': ['Rikitea', 'Vaini', 'Kapaa', 'Arraial do Cabo', 'Yellowknife', 'Busselton', "Oktyabr'skiy", 'Maniitsoq', 'Shangzhi', 'Albany', 'Grand Gaube', 'Cherskiy', 'Hilo', 'Bluff', 'Rio Grande', 'Lebu', 'Hong Kong', 'Zolochiv', 'Ribeira Grande', 'Huilong', 'Mataura', 'Malanje', 'Swanzey', 'Cap Malheureux', 'Tiksi', 'Bud', 'Cabedelo', 'Cidreira', 'Ushuaia', 'Meulaboh', 'Ozinki', 'George Town', 'Hermanus', 'Chapais', 'Port Keats', 'Kumul', 'Bengkulu', 'Khatanga', 'Saint George', 'Tuktoyaktuk', 'Iqaluit', 'Hambantota', 'Tasiilaq', 'Tuatapere', 'Puerto Ayora', 'Saint-Philippe', 'Tadine', 'Narsaq', 'Guápiles', 'Hobart', 'Ust-Tsilma', 'Punta Arenas', 'Tiznit Province', 'Chokurdakh', 'Bambous Virieux', 'Vyshestebliyevskaya', 'Saint Paul Harbor', 'Esperance', 'Camacha', 'Atuona', 'West Plains', 'Barrow', 'Thunder Bay', 'Dikson', 'Aquiraz', 'Portel', 'Cabo San Lucas', 'Soure', 'Saskylakh', 'Butaritari', 'Atar', 'Hithadhoo', 'Oranjemund', 'Chernyshevskiy', 'Carnarvon', 'Darovskoy', 'Flin Flon', 'Kaitangata', 'Westfield', 'Northam', 'Yinchuan', 'Williamsburg', 'Tulagi', 'Katsuura', 'Prince George', 'Shimoda', 'Beringovskiy', 'Thompson', 'Port Elizabeth', 'São João da Barra', 'San Cristobal', 'Castro', 'Codrington', 'Upernavik', "Ust'-Shonosha", 'Husavik', 'Sobolevo', 'Vila', 'Dera Bugti', 'Constitución', 'Kruisfontein', 'Avarua', 'Najrān', 'Leningradskiy', 'Norman Wells', 'Belyy Yar', 'Rocha', 'Jamestown', 'Cayenne', 'Mahébourg', 'Nome', 'Half Moon Bay', 'Tarifa', 'Rodolfo Sánchez Taboada', 'Clyde River', 'Yurginskoye', 'Moosomin', 'Ancud', 'Yerbogachën', 'Praia da Vitória', 'Richards Bay', 'Kanigoro', 'Izhevskoye', 'Verkhnevilyuysk', 'Vardø', 'Naze', 'Riyadh', 'East London', 'Nikolskoye', 'Qaanaaq', 'Flinders', 'Banepā', 'Manokwari', 'Kārkala', 'Qingquan', 'Sarakhs', 'Arica', 'Santa Rosa', 'Poya', 'Puri', 'New Norfolk', 'Huarmey', "Zabaykal'sk", 'Aksu', 'Lorengau', 'Faanui', 'Port Blair', 'Broome', 'Coyhaique', 'Beloha', 'Pangnirtung', 'Mahenge', "Mezen'", 'Geraldton', 'Pevek', 'Sitia',
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Rikitea -23.12 -134.97     23.56        80          28
# 1              Vaini -21.20 -175.20     24.00        94          40
# 2              Kapaa  22.08 -159.32     25.00        78          90
# 3    Arraial do Cabo -22.97  -42.03     28.00        74          75
# 4        Yellowknife  62.46 -114.35    -15.00        92          40
# ..               ...    ...     ...       ...       ...         ...
# 554      Bongandanga   1.50   21.05     26.11        67          95
# 555      San Quintín  30.48 -115.95     18.86        54           0
# 556          Kajiado  -1.85   36.78     19.00        82          75
# 557        Mongoumba   3.64   18.59     25.18        71          30
# 558       Hammerfest  70.66   23.68      5.00        80          75
#
#      Wind Speed Country        Date
# 0          7.39      PF  1605290420
# 1          3.10      TO  1605290420
# 2          8.70      US  1605290420
# 3          4.60      BR  1605290421
# 4          3.10      CA  1605290421
# ..          ...     ...         ...
# 554        1.36      CD  1605290524
# 555        2.89      MX  1605290525
# 556        5.10      KE  1605290525
# 557        1.15      CF  1605290525
# 558        3.10      NO  1605290525
#
# [559 rows x 9 columns]

# %%
#output to cvs
weather_df.to_csv(output_data_file_2)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  585.000000  585.000000  585.000000  585.000000  585.000000  585.000000
# mean    19.971504   19.615094   14.359197   73.054701   48.820513    3.382581
# std     33.514728   89.146433   13.872409   19.757097   41.612493    2.438111
# min    -54.800000 -179.170000  -31.350000   15.000000    0.000000    0.050000
# 25%     -8.140000  -58.650000    3.580000   63.000000    1.000000    1.500000
# 50%     22.790000   26.920000   18.830000   77.000000   43.000000    2.680000
# 75%     48.830000   98.630000   25.670000   88.000000   90.000000    4.630000
# max     78.220000  179.320000   36.570000  100.000000  100.000000   12.900000
#
#                Date
# count  5.850000e+02
# mean   1.605034e+09
# std    7.482059e+01
# min    1.605034e+09
# 25%    1.605034e+09
# 50%    1.605034e+09
# 75%    1.605035e+09
# max    1.605035e+09

# %%
#  Get the indices of cities that have humidity over 100%.

too_humid = weather_df.loc[weather_df["Humidity"] >= 100, :]

#print(too_humid)

#put humid city index numbers into a list
too_humid.index

#print(humid_outliers)
# Out:
# Int64Index([23, 81, 188, 249, 279, 305, 364, 376, 381, 406, 407, 513, 537], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#drop rows by index
# index values were added in manually...can I make them a variable?

weather_clean_df = weather_df.drop([23, 81, 188, 249, 279, 305, 364, 376, 381, 406, 407, 513, 537])

weather_clean_df.count
# Out:
# <bound method DataFrame.count of                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Rikitea -23.12 -134.97     23.56        80          28
# 1              Vaini -21.20 -175.20     24.00        94          40
# 2              Kapaa  22.08 -159.32     25.00        78          90
# 3    Arraial do Cabo -22.97  -42.03     28.00        74          75
# 4        Yellowknife  62.46 -114.35    -15.00        92          40
# ..               ...    ...     ...       ...       ...         ...
# 554      Bongandanga   1.50   21.05     26.11        67          95
# 555      San Quintín  30.48 -115.95     18.86        54           0
# 556          Kajiado  -1.85   36.78     19.00        82          75
# 557        Mongoumba   3.64   18.59     25.18        71          30
# 558       Hammerfest  70.66   23.68      5.00        80          75
#
#      Wind Speed Country        Date
# 0          7.39      PF  1605290420
# 1          3.10      TO  1605290420
# 2          8.70      US  1605290420
# 3          4.60      BR  1605290421
# 4          3.10      CA  1605290421
# ..          ...     ...         ...
# 554        1.36      CD  1605290524
# 555        2.89      MX  1605290525
# 556        5.10      KE  1605290525
# 557        1.15      CF  1605290525
# 558        3.10      NO  1605290525
#
# [546 rows x 9 columns]>

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#setup variables for plotting
city_lat = weather_clean_df["Lat"]
max_temp = weather_clean_df["Max Temp"]

#generate scatter plot
plt.title('City Latitude vs. Temperature (11/10/2020)')
plt.scatter(city_lat,max_temp,edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",linestyle="--", axis="both")
plt.show()
print(f"It appears that it is actually warmer near the equator.")
#plt.savefig("output_data/fig1.png")
# Out:
# It appears that it is actually warmer near the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#setup variables plotting
city_lat = weather_clean_df["Lat"]
humidity = weather_clean_df["Humidity"]

#generate scatter plot
plt.title('City Latitude vs. Humidity (11/10/2020)')
plt.scatter(city_lat,humidity,edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid (b=True,which="major",linestyle="--", axis="both")
plt.show()
print(f"Is there any relationship between the humidity and latitude of a city?")
#plt.savefig("output_data/fig2.png")
# Out:
# Is there any relationship between the humidity and latitude of a city?

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#setup variables for plotting
city_lat = weather_clean_df["Lat"]
cloudiness = weather_clean_df["Cloudiness"]

#generate scatter plot
plt.title('City Latitude vs. Cloudiness (11/10/2020)')
plt.scatter(city_lat,cloudiness,edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid (b=True,which="major",linestyle="--", axis="both")
plt.show()
print(f"Is a city's cloudiness determined in any way by it's latitude? Probably not.")
#plt.savefig("output_data/fig3.png")
# Out:
# Is a city's cloudiness determined in any way by it's latitude? Probably not.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#setup variables for plotting
city_lat = weather_clean_df["Lat"]
wind_speed = weather_clean_df["Wind Speed"]

#generate scatter plot
plt.title('City Latitude vs. Wind Speed (11/10/2020)')
plt.scatter(city_lat,wind_speed,edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid (b=True,which="major",linestyle="--", axis="both")
plt.show()
print(f"Any relationship between a city's latitude and wind speed?")
#plt.savefig("output_data/fig4.png")
# Out:
# Any relationship between a city's latitude and wind speed?.

# %% [markdown]
# ## Linear Regression

# %%
#set up data and variables for plotting.  Northern hemisphere vs Southern city data.

#northern hemi cities
n_city_lat = weather_clean_df[weather_clean_df['Lat'] >= 0]


# #southern hemi cities
s_city_lat = weather_clean_df[weather_clean_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = n_city_lat["Lat"]
max_temp = n_city_lat["Max Temp"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = max_temp

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1,-20),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression (11/10/2020) \n')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
print(f"This plot shows that there is a correlation between max temperatrue and a city's latitude.")

#plt.savefig("output_data/fig5.png")
# Out:
#           The r-squared is: 0.7855608288363719
# This plot shows that there is a correlation between max temperatrue and a city's latitude.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

#southern hemi cities
city_lat = s_city_lat["Lat"]
max_temp = s_city_lat["Max Temp"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = max_temp

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression (11/10/2020) \n')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

print(f"low correlation between temp and latitidue.")

#plt.savefig("output_data/fig6.png")
# Out:
#           The r-squared is: 0.401007341027448
# low correlation between temp and latitidue.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = n_city_lat["Lat"]
humidity = n_city_lat["Humidity"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(43,27),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression  (11/10/2020) \n')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

print(f"Plot shows low correlation between humidity and a city's latitude.")

#plt.savefig("output_data/fig7.png")
# Out:
#           The r-squared is: 0.1653067866636731
# Plot shows low correlation between humidity and a city's latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = s_city_lat["Lat"]
humidity = s_city_lat["Humidity"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-56,18),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression (11/10/2020) \n')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

print(f"No relationship between humidty and a city's latitude.")

plt.savefig("output_data/fig8.png")
# Out:
#           The r-squared is: 0.019765083861623345
# No relationship between humidty and a city's latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = n_city_lat["Lat"]
cloudiness = n_city_lat["Cloudiness"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(36,25),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression \n')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

print(f"Plot is show low correlation between max temperatrue and a city's latitude.")

#plt.savefig("output_data/fig9.png")
# Out:
#           The r-squared is: 0.05929109401449708
# Plot is show low correlation between max temperatrue and a city's latitude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = s_city_lat["Lat"]
cloudiness = s_city_lat["Cloudiness"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-44,51),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression \n')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

print(f"Plot is show low correlation between max temperatrue and a city's latitude.")

plt.savefig("output_data/fig10.png")
# Out:
#           The r-squared is: 0.10604311047567287
# Plot is show low correlation between max temperatrue and a city's latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = n_city_lat["Lat"]
wind_speed = n_city_lat["Wind Speed"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = wind_speed

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1,10),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression \n')
plt.xlabel('Latitude')
plt.ylabel('Wind Steep')
plt.show()

print(f"Plot is show low correlation between max temperatrue and a city's latitude.")

#plt.savefig("output_data/fig11.png")
# Out:
#           The r-squared is: 0.031320485325921486
# Plot is show low correlation between max temperatrue and a city's latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#setup x and y variables for plotting

city_lat = s_city_lat["Lat"]
wind_speed = s_city_lat["Wind Speed"]


#calculate the correlation coefficent and linear regression model
x_values = city_lat
y_values = wind_speed

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#plot the graph and print the r-squared value
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,9),fontsize=16,color="red")
print(f"          The r-squared is: {rvalue**2}")
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression \n')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

print(f"Plot shows no real relationship between max temperatrue and a city's latitude.")

#plt.savefig("output_data/fig12.png")
# Out:
#           The r-squared is: 0.033679789882142354
# Plot shows no real relationship between max temperatrue and a city's latitude.
